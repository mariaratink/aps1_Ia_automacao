# %% [markdown]
# APS1 - Projeto de Aprendizado de Máquina

# %% [markdown]
# Classificador de falhas de aplicações industriais acionadas
# por motores elétricos para máquinas rotativas

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix, ConfusionMatrixDisplay

# %%
base_de_dados = pd.read_csv('Dataset APS1_Sinais Eletricos e Vibracao_csv.xls')
base_de_dados
# Out:
#       tempo_s  tipo_setup  I_entrada_A  P_entrada_W  I_saida_A  \
# 0        0.00         0.0      0.44905     63.67320    1.43660
# 1        0.08         0.0      0.44610     69.40320    1.67860
# 2        0.16         0.0      0.45175     69.11385    1.39950
# 3        0.24         0.0      0.43510     68.85665    1.39705
# 4        0.32         0.0      0.45055     70.52860    1.43375
# ...       ...         ...          ...          ...        ...
# 2500    39.68         4.0      0.46575     68.42795    1.59235
# 2501    39.76         4.0      0.44705     62.32815    1.57365
# 2502    39.84         4.0      0.47110     76.04075    1.77275
# 2503    39.92         4.0      0.47745     72.86850    1.39700
# 2504    40.00         4.0      0.48705     70.70715    1.51215
#
#       DesvPad_I_entrada_A  DesvPad _P_entrada_W  DesvPad _I_saida_A  \
# 0                0.042740             21.869566            0.113479
# 1                0.048945              1.600020            0.854342
# ...

# %%
from sklearn.model_selection import train_test_split  # usado para embaralhar e separar os dados de treino e teste
train_data, test_data = train_test_split(base_de_dados, test_size=0.20, random_state=1, shuffle=True)

# Exibir os dados de treinamento
train_data
# Out:
#       tempo_s  tipo_setup  I_entrada_A  P_entrada_W  I_saida_A  \
# 1861    28.64         3.0      0.47090     73.28460    1.67270
# 2207    16.24         4.0      0.44730     65.62895    1.45840
# 2173    13.52         4.0      0.47470     68.76740    1.46830
# 1727    17.92         3.0      0.48265     70.03370    1.50705
# 2243    19.12         4.0      0.47175     69.09600    1.57565
# ...       ...         ...          ...          ...        ...
# 960     36.72         1.0      0.44775     63.13915    1.43420
# 905     32.32         1.0      0.43720     68.74225    1.43555
# 1096     7.52         2.0      0.52095     78.50375    1.27830
# 235     18.80         0.0      0.43570     65.50565    1.38210
# 1061     4.72         2.0      0.52900     91.51080    1.42345
#
#       DesvPad_I_entrada_A  DesvPad _P_entrada_W  DesvPad _I_saida_A  \
# 1861             0.005902              2.734395            0.638069
# 2207             0.067206              0.870145            0.654890
# ...
